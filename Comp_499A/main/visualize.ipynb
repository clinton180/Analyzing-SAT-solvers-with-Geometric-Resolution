# %%
from sample import sample

sampletest = sample()
print(sampletest)
# Out:
# Generating relation_1 with attributes ['v1', 'v2']
# Saved relation_1.csv
# Generating relation_2 with attributes ['v2', 'v3']
# Saved relation_2.csv
# Generating relation_3 with attributes ['v1', 'v3']
# Saved relation_3.csv
# 43
# ...
